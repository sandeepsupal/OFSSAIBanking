# %% [markdown]
# $$\huge{\textbf{Financial Sentimental Analysis}}$$

# %% [markdown]
# # Problem Statement

# %% [markdown]
# The main task is to detect the tone of the financial text i.e, positive,negative or neutral using Deep Learning approaches.

# %% [markdown]
# # Dataset description

# %% [markdown]
# The following data is intended for advancing financial sentiment analysis research.

# %% [markdown]
# # Methodology

# %% [markdown]
# The methodology of the assigment is going to includes the following
#
# 1. Data preprocessing:
#
# Data preprocessing includes tokenization, vectorization and train test splitting of data for model training.
#
# 2. Models: The model that are going to be used to train the data is Basic LSTM

# %% [markdown]
# ## Data preprocessing

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 4.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/harshit/.local/lib/python3.10/site-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: jinja2 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (22.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (59.6.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: pathy>=0.3.5 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/harshit/.local/lib/python3.10/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/harshit/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/harshit/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/harshit/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/harshit/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/harshit/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/harshit/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/harshit/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import numpy as np
import plotly.express as pe
import os
import matplotlib.pyplot as plt
import text_hammer as th
import warnings
from tensorflow import keras
warnings.filterwarnings('ignore')
from tqdm import tqdm_notebook as tqdm
# Out:
# 2023-01-12 17:37:10.278100: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-12 17:37:19.735031: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-12 17:37:19.735065: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-12 17:37:20.917313: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-12 17:37:20.917627: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-12 17:37:20.917639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # load data with news headlines

# %%
df = pd.read_csv('/home/harshit/Desktop/OFSSAIBanking/data.csv')

# %%
df.head(10)
# Out:
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral
# 5    $SPY wouldn't be surprised to see a green close  positive
# 6  Shell's $70 Billion BG Deal Meets Shareholder ...  negative
# 7  SSH COMMUNICATIONS SECURITY CORP STOCK EXCHANG...  negative
# 8  Kone 's net sales rose by some 14 % year-on-ye...  positive
# 9  The Stockmann department store will have a tot...   neutral

# %%
df['len'] = list(map(lambda x: len(str(x).split(' ')),df['Sentence']))
df.head()
# Out:
#                                             Sentence Sentiment  len
# 0  The GeoSolutions technology will leverage Bene...  positive   32
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative   11
# 2  For the last quarter of 2010 , Componenta 's n...  positive   39
# 3  According to the Finnish-Russian Chamber of Co...   neutral   20
# 4  The Swedish buyout firm has sold its remaining...   neutral   23

# %%
mapdf = {'positive':0,'negative':1,'neutral':2}
df['Sentiment'] = list(map(lambda x:mapdf[x],df['Sentiment']))
df.head()
# Out:
#                                             Sentence  Sentiment  len
# 0  The GeoSolutions technology will leverage Bene...          0   32
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...          1   11
# 2  For the last quarter of 2010 , Componenta 's n...          0   39
# 3  According to the Finnish-Russian Chamber of Co...          2   20
# 4  The Swedish buyout firm has sold its remaining...          2   23

# %%
print(df['Sentiment'].corr(df['len']))
# Out:
# 0.10137114484667775

# %%
sentences = df['Sentence'].copy()[:]
sentences = sentences.to_list()
sentences = list(map(lambda x: x.lower(),sentences))
sentences = list(map(lambda x: th.cont_exp(x),sentences))
sentences = list(map(lambda x: th.remove_emails(x),sentences))
sentences = list(map(lambda x: th.remove_emails(x),sentences))
sentences = list(map(lambda x: th.remove_html_tags(x),sentences))
sentences = list(map(lambda x: th.remove_stopwords(x),sentences))
sentences = list(map(lambda x: th.remove_special_chars(x),sentences))
sentences = list(map(lambda x: th.remove_accented_chars(x),sentences))
sentences = list(map(lambda x: th.make_base(x),sentences))

# %%
sentences[:3]
# Out:
# ['geosolution technology leverage benefon global positioning system solution provide location base search technology community platform location relevant multimedia content new powerful commercial model',
#  'esi low 150 250 bk real possibility',
#  'quarter 2010 componenta net sale double eur131 m eur76 m period year early move zero pretax profit pretax loss eur7 m']

# %%
import nltk
nltk.download('all')
pairs = []
for sent in tqdm(sentences):
    pairs.extend(nltk.word_tokenize(sent))
freq = nltk.FreqDist(pairs)
freq.most_common(10)
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /home/harshit/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/harshit/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
#   0%|          | 0/5842 [00:00<?, ?it/s]
# [('eur', 1284),
#  ('company', 917),
#  ('mn', 729),
#  ('sale', 604),
#  ('profit', 584),
#  ('say', 574),
#  ('finnish', 527),
#  ('share', 512),
#  ('net', 499),
#  ('million', 493)]

# %%
tempdf = pd.DataFrame(freq.most_common(10),  columns=['word', 'count'])
pe.bar(x='word',y='count',data_frame=tempdf, title="Top 10 words")

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
y = to_categorical(df['Sentiment'])
x = sentences.copy()
X_train,X_test, y_train,y_test = train_test_split(x,y,test_size=0.3,stratify=y,random_state=42)

# %% [markdown]
# ### Word Embeddings
# Luckily there is a third method that is far superior, **word embeddings**. This method keeps the order of words intact as well as encodes similar words with very similar labels. It attempts to not only encode the frequency and order of words but the meaning of those words in the sentence. It encodes each word as a dense vector that represents its context in the sentence.
#
# Unlike the previous techniques word embeddings are learned by looking at many different training examples. You can add what's called an *embedding layer* to the beggining of your model and while your model trains your embedding layer will learn the correct embeddings for words. You can also use pretrained embedding layers.
#
# This is the technique we will use for our examples and its implementation will be showed later on.

# %% [markdown]
# ## Vectorization

# %% [markdown]
# Word Embeddings or Word vectorization is a methodology in NLP to map words or phrases from vocabulary to a corresponding vector of real numbers which used to find word predictions, word similarities/semantics.

# %%
from keras.preprocessing.text import Tokenizer
num_words = 12000 
tokenizer=Tokenizer(num_words,lower=True)
df_total = pd.concat([pd.Series(X_train), pd.Series(X_test)], axis = 0)
tokenizer.fit_on_texts(df_total)

# %% [markdown]
# ## padding to ensure consistent length

# %%
from keras.utils import pad_sequences

X_train_ =tokenizer.texts_to_sequences(X_train)
X_train_pad=pad_sequences(X_train_,maxlen=81,padding='post')
X_test_ = tokenizer.texts_to_sequences(X_test)
X_test_pad = pad_sequences(X_test_, maxlen = 81, padding = 'post')

# %%
print(X_train_pad.shape,X_test_pad.shape)
# Out:
# (4089, 81) (1753, 81)

# %% [markdown]
# ## LSTM

# %% [markdown]
# ##Recurrent Neural Networks (RNN's)
# Now that we've learned a little bit about how we can encode text it's time to dive into recurrent neural networks. Up until this point we have been using something called **feed-forward** neural networks. This simply means that all our data is fed forwards (all at once) from left to right through the network. This was fine for the problems we considered before but won't work very well for processing text. After all, even we (humans) don't process text all at once. We read word by word from left to right and keep track of the current meaning of the sentence so we can understand the meaning of the next word. Well this is exaclty what a recurrent neural network is designed to do. When we say recurrent neural network all we really mean is a network that contains a loop. A RNN will process one word at a time while maintaining an internal memory of what it's already seen. This will allow it to treat words differently based on their order in a sentence and to slowly build an understanding of the entire input, one word at a time.
#
# This is why we are treating our text data as a sequence! So that we can pass one word at a time to the RNN.
#
# Let's have a look at what a recurrent layer might look like.
#
# ![alt text](https://colah.github.io/posts/2015-08-Understanding-LSTMs/img/RNN-unrolled.png)
# *Source: https://colah.github.io/posts/2015-08-Understanding-LSTMs/*
#
# Let's define what all these variables stand for before we get into the explination.
#
# **h<sub>t</sub>** output at time t
#
# **x<sub>t</sub>** input at time t
#
# **A** Recurrent Layer (loop)
#
# What this diagram is trying to illustrate is that a recurrent layer processes words or input one at a time in a combination with the output from the previous iteration. So, as we progress further in the input sequence, we build a more complex understanding of the text as a whole.
#
# What we've just looked at is called a **simple RNN layer**. It can be effective at processing shorter sequences of text for simple problems but has many downfalls associated with it. One of them being the fact that as text sequences get longer it gets increasingly difficult for the network to understand the text properly.

# %%
from keras.models import Sequential
from keras.layers import LSTM,Dense,Bidirectional,Embedding,Dropout

# %%
lstm = Sequential()
lstm.add(Embedding(input_dim = num_words,
                          output_dim = 100,
                          input_length= X_train_pad.shape[1]))
lstm.add(Dropout(0.2))
lstm.add(Bidirectional(LSTM(128,return_sequences=True)))
lstm.add(Dropout(0.2))
lstm.add(Bidirectional(LSTM(256,return_sequences=True)))
lstm.add(Dropout(0.2))
lstm.add(Bidirectional(LSTM(128,return_sequences=False)))
lstm.add(Dense(64,activation='tanh'))
lstm.add(Dense(32,activation='tanh'))
lstm.add(Dense(10,activation='tanh'))
lstm.add(Dense(3,activation='softmax'))
# Out:
# 2023-01-12 17:41:10.108059: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-01-12 17:41:10.108113: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-12 17:41:10.108136: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ideapad.techficent.com): /proc/driver/nvidia/version does not exist
# 2023-01-12 17:41:10.108890: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
lstm.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 81, 100)           1200000
#
#  dropout (Dropout)           (None, 81, 100)           0
#
#  bidirectional (Bidirectiona  (None, 81, 256)          234496
#  l)
#
#  dropout_1 (Dropout)         (None, 81, 256)           0
#
#  bidirectional_1 (Bidirectio  (None, 81, 512)          1050624
#  nal)
#
#  dropout_2 (Dropout)         (None, 81, 512)           0
#
#  bidirectional_2 (Bidirectio  (None, 256)              656384
#  nal)
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 10)                330
#
#  dense_3 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 3,160,395
# Trainable params: 3,160,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 5)
mc = ModelCheckpoint('./model.h5', monitor = 'val_accuracy', mode = 'max', verbose = 1, save_best_only = True)

# %%
lstm_history = lstm.fit(X_train_pad,y_train, epochs = 10, batch_size = 64, validation_data=(X_test_pad, y_test),verbose = 1, callbacks= [es, mc])
# Out:
# Epoch 1/10
# 64/64 [==============================] - ETA: 0s - loss: 0.9396 - accuracy: 0.5679
# Epoch 1: val_accuracy improved from -inf to 0.65431, saving model to ./model.h5
# 64/64 [==============================] - 100s 1s/step - loss: 0.9396 - accuracy: 0.5679 - val_loss: 0.8181 - val_accuracy: 0.6543
# Epoch 2/10
# 64/64 [==============================] - ETA: 0s - loss: 0.6223 - accuracy: 0.7449
# Epoch 2: val_accuracy improved from 0.65431 to 0.67827, saving model to ./model.h5
# 64/64 [==============================] - 81s 1s/step - loss: 0.6223 - accuracy: 0.7449 - val_loss: 0.7260 - val_accuracy: 0.6783
# Epoch 3/10
# 64/64 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.8491
# Epoch 3: val_accuracy did not improve from 0.67827
# 64/64 [==============================] - 89s 1s/step - loss: 0.3796 - accuracy: 0.8491 - val_loss: 0.7785 - val_accuracy: 0.6526
# Epoch 4/10
# 64/64 [==============================] - ETA: 0s - loss: 0.2532 - accuracy: 0.8921
# Epoch 4: val_accuracy did not improve from 0.67827
# 64/64 [==============================] - 104s 2s/step - loss: 0.2532 - accuracy: 0.8921 - val_loss: 0.9643 - val_accuracy: 0.6549
# Epoch 5/10
# 64/64 [==============================] - ETA: 0s - loss: 0.2031 - accuracy: 0.9002
# Epoch 5: val_accuracy did not improve from 0.67827
# 64/64 [==============================] - 99s 2s/step - loss: 0.2031 - accuracy: 0.9002 - val_loss: 1.1078 - val_accuracy: 0.6549
# Epoch 6/10
# 64/64 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9120
# Epoch 6: val_accuracy did not improve from 0.67827
# 64/64 [==============================] - 95s 1s/step - loss: 0.1804 - accuracy: 0.9120 - val_loss: 1.1908 - val_accuracy: 0.6423
# Epoch 7/10
# 64/64 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9171
# Epoch 7: val_accuracy did not improve from 0.67827
# 64/64 [==============================] - 98s 2s/step - loss: 0.1699 - accuracy: 0.9171 - val_loss: 1.1955 - val_accuracy: 0.6509
# Epoch 7: early stopping

# %%
plt.plot(lstm_history.history['accuracy'], label='Train Data')
plt.plot(lstm_history.history['val_accuracy'], label='Test Data')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
#plt.ylim([0.8, 1])
plt.legend(loc='best')
plt.show()

# %%
plt.plot(lstm_history.history['loss'], label='Train loss')
plt.plot(lstm_history.history['val_loss'], label='Test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import classification_report
predictions = lstm.predict(X_test_pad)
target_names=['positive','negative','neutral']
print(classification_report(np.argmax(y_test,axis=1),np.argmax(predictions,axis=1),target_names=target_names))
# Out:
# 55/55 [==============================] - 13s 233ms/step
#               precision    recall  f1-score   support
#
#     positive       0.68      0.68      0.68       556
#     negative       0.30      0.26      0.28       258
#      neutral       0.71      0.74      0.73       939
#
#     accuracy                           0.65      1753
#    macro avg       0.56      0.56      0.56      1753
# weighted avg       0.64      0.65      0.65      1753
